# %% [markdown]
# <a href="https://colab.research.google.com/github/Waleed-Ahmed01/RTFM_2/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import ViTFeatureExtractor

model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1dc16340affe> in <module>
# ----> 1 from transformers import ViTFeatureExtractor
#       2
#       3 model_name_or_path = 'google/vit-base-patch16-224-in21k'
#       4 feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
#
# ModuleNotFoundError: No module named 'transformers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q git+https://github.com/huggingface/transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 7.6 MB 5.2 MB/s
#      |████████████████████████████████| 163 kB 67.7 MB/s
# ...

# %%
from transformers import ViTFeatureExtractor, ViTModel
from transformers import ImageFeatureExtractionMixin
import torch
import cv2
image=cv2.imread('image.jpe')
#from datasets import 
feature_extractor = ViTFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")
inputs = feature_extractor(image,return_tensors="np")

# %%
print(inputs)
# Out:
# {'pixel_values': array([[[[-0.49019605, -0.01176465,  0.5450982 , ...,  0.45882356,
#            0.45882356,  0.48235297],
#          [-0.51372546, -0.2156862 ,  0.36470592, ...,  0.45882356,
#            0.4666667 ,  0.47450984],
#          [-0.5921568 , -0.38823527,  0.254902  , ...,  0.4666667 ,
#            0.45882356,  0.47450984],
#          ...,
#          [-0.8117647 , -0.8117647 , -0.8117647 , ..., -0.79607844,
#           -0.79607844, -0.79607844],
#          [-0.8117647 , -0.8117647 , -0.8117647 , ..., -0.79607844,
#           -0.79607844, -0.79607844],
#          [-0.8117647 , -0.8117647 , -0.8117647 , ..., -0.79607844,
#           -0.79607844, -0.79607844]],
#
#         [[ 0.07450986,  0.4666667 ,  0.8901962 , ...,  0.14509809,
#            0.13725495,  0.12941182],
#          [ 0.09803927,  0.30196083,  0.74901974, ...,  0.15294123,
#            0.14509809,  0.13725495],
#          [ 0.09019613,  0.20000005,  0.70980406, ...,  0.16078436,
# ...

# %%
# !pip install -qq medmnist
# Out:
#      |████████████████████████████████| 87 kB 3.2 MB/s
# ...

# %%
import os
import io
import imageio
import medmnist
import ipywidgets
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Setting seed for reproducibility
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)

# %%
# DATA
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
import numpy as np
import cv2
import os

cap = cv2.VideoCapture('01_001.avi')
from google.colab.patches import cv2_imshow
ret, frame = cap.read()
if ret == True:
    cv2_imshow(frame)
    # 20 is in milliseconds, try to increase the value, say 50 and observe
    key = cv2.waitKey(20)
print(ret)
print(np.shape(frame))
# Out:
# <PIL.Image.Image image mode=RGB size=856x480 at 0x7F09F56AD3D0>
# True
# (480, 856, 3)

# %%
if ret == True:
    cv2.imshow('Frame',frame)
    # 20 is in milliseconds, try to increase the value, say 50 and observe
    key = cv2.waitKey(20)
